# %% [markdown]
# <a href="https://colab.research.google.com/github/ykjoy/data_visualization/blob/main/Data_Visualization_practice_0824.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization in Python
#
# ---
# 1. *Matplotlib*
# 2. *Pandas and Seaborn*
# 3. *More plots and maps with Folium*
# 4. <font color='red'>Practice </font>
# ---

# %%
# set up the notebook for plotting and import the packages 

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
import folium
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# #  Datasets for Practice

# %% [markdown]
# (1)  World Happiness Score: https://raw.githubusercontent.com/ykjoy/data_visualization/main/World_Happiness_2022.csv
#
# (2) Gender Inequality Index: https://raw.githubusercontent.com/ykjoy/data_visualization/main/Gender_Inequality_2019.csv
#
# (3) Gender Development Index: https://raw.githubusercontent.com/ykjoy/data_visualization/main/Gender_Development_2019.csv

# %% [markdown]
# ###  World Happiness dataset
#
# This dataset can be obtained from [World Happiness Report](https://worldhappiness.report/ed/2022/#appendices-and-data)
#
# * **Happiness score**: Happiness scores are calculated from global survey data on how people evaluate their own lives in more than 150 countries worldwide.
# * **GDP per capita**: At its most basic interpretation, per capita GDP shows how much economic production value can be attributed to each individual citizen. Alternatively, this translates to a measure of national wealth since GDP market value per person also readily serves as a prosperity measure.
# *  **Social support**:  Social support is defined in terms of social network characteristics such as assistance from family, friends, neighbours and other community members.
# * **Healthy life expectancy**: Healthy life expectancy is the average life in good health - that is to say without irreversible limitation of activity in daily life or incapacities - of a fictitious generation subject to the conditions of mortality and morbidity prevailing that year.
# * **Freedom to make life choices**: Freedom of choice describes an individual's opportunity and autonomy to perform an action selected from at least two available options, unconstrained by external parties.
# * **Generosity**: Generosity is the virtue of being liberal in giving, often as gifts.
# * **Perceptions of corruption**: Corruption is a form of dishonesty or criminal offense undertaken by a person or organization entrusted with a position of authority, to acquire illicit benefit.
#
# ** Each variable measures a populated-weighted average score on a scale of 0-10 that is tracked over a period of time and also further compared with other nations.

# %%
happy_path = "https://raw.githubusercontent.com/ykjoy/data_visualization/main/World_Happiness_2022.csv"
happy_df = pd.read_csv(happy_path)
happy_df.head()
# Out:
#    RANK      Country          Region  Happiness score  GDP per capita  \
# 0     1      Finland  Western Europe            7.821           1.892
# 1     2      Denmark  Western Europe            7.636           1.953
# 2     3      Iceland  Western Europe            7.557           1.936
# 3     4  Switzerland  Western Europe            7.512           2.026
# 4     5  Netherlands  Western Europe            7.415           1.945
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.258                    0.775                         0.736
# 1           1.243                    0.777                         0.719
# 2           1.320                    0.803                         0.718
# 3           1.226                    0.822                         0.677
# 4           1.206                    0.787                         0.651
#
#    Generosity  Perceptions of corruption
# 0       0.109                      0.534
# ...

# %% [markdown]
# ### Gender Inequality Index and Gender Development Index
#
# These two datasets can be obtained from [Human Development Reports (Tables 4 & 5) ](https://hdr.undp.org/data-center/documentation-and-downloads/)
#
# The Gender Inequality Index (GII) and the Gender Development Index (GDI) are the indices proposed by the United Nations Development Programme (UNDP) to assess the position of women in society. However, they give us distinct information on gender inequalities:
# * GII is a composite metric of gender inequality using three dimensions: reproductive health, empowerment and the labour market. A **low** GII value indicates **low inequality** between women and men, and vice-versa.
#
#     *   Country, GII Value, GII Rank
#     *   Maternal mortality ratio (deaths per 100,000 live births), Adolescent birth rate (births per 1,000 women ages 15–19)
#     * Share of seats in parliament (% held by women)
#     * Female population with secondary education (% ages 25 and older), Male population with secondary education (% ages 25 and older)
#     * Female labour force participation rate (% ages 15 and older), Male labour force participation rate (% ages 15 and older)
#
#
# * GDI is a direct measure of gender gaps in human development achievements in three basic areas of human development: health, education, and command over economic resources (the female Human Development Index expressed as a percentage of the male HDI).  Countries are divided into five groups: both gender disparities favouring males and those favouring females are taken into account when categorising.
#
#     * Country, GDI Value, GDI Group, Female HDI, Male HDI, HDI Rank
#     * Female life expectancy at birth (years), Male life expectancy at birth (years)
#     * Female mean years of schooling (years), Male mean years of schooling (years)

# %%
gii_path = "https://raw.githubusercontent.com/ykjoy/data_visualization/main/Gender_Inequality_2019.csv"
gii_df = pd.read_csv(gii_path)
gii_df.head()
# Out:
#        Country  GII Value  GII Rank  Maternal mortality ratio  \
# 0  Switzerland      0.025         1                         5
# 1      Denmark      0.038         2                         4
# 2       Sweden      0.039         3                         4
# 3  Netherlands      0.043         4                         5
# 4      Belgium      0.043         4                         5
#
#    Adolescent birth rate  Share of seats in parliament  \
# 0                    2.8                          38.6
# 1                    4.1                          39.1
# 2                    5.1                          47.3
# 3                    3.8                          33.8
# 4                    4.7                          43.3
#
#    Female population with secondary education  \
# 0                                        95.6
# 1                                        91.2
# 2                                        89.3
# 3                                        87.6
# ...

# %%
gdi_path = "https://raw.githubusercontent.com/ykjoy/data_visualization/main/Gender_Development_2019.csv"
gdi_df = pd.read_csv(gdi_path)
gdi_df.head()
# Out:
#      Country  GDI Value  GDI Group  Female HDI  Male HDI  \
# 0     Latvia   1.035955          2    0.879288  0.848770
# 1  Lithuania   1.029916          2    0.894191  0.868218
# 2      Qatar   1.029675          2    0.865982  0.841025
# 3   Mongolia   1.023089          1    0.743857  0.727069
# 4     Panama   1.019028          1    0.826086  0.810661
#
#    Female life expectancy at birth  Male life expectancy at birth  \
# 0                           80.012                         70.233
# 1                           81.371                         70.294
# 2                           82.010                         79.142
# 3                           74.142                         65.799
# 4                           81.756                         75.421
#
#    Female mean years of schooling  Male mean years of schooling  HDI Rank
# 0                       13.447497                     12.551105        37
# 1                       13.100240                     13.048000        34
# ...

# %% [markdown]
# ##  (Tips: Read  and write data files from your Google Drive)
#
# You can access files in Drive by mounting your Google Drive in the runtime's virtual machine.
#
# *    Reference: https://colab.research.google.com/notebooks/io.ipynb`

# %%
## You need to mount google drive to your Colab session. (Go to the link to retrieve the authorization code.)

## from google.colab import drive
## drive.mount('/content/drive')

# %%
## You can read files from your Google Drive.
## wisc = pd.read_csv("/content/drive/My Drive/Colab Notebooks/YOURDRIVE/wisc_bc_data.csv", index_col='id')

# %%
## You can also write to google drive as follows:

## with open('/content/drive/My Drive/Colab Notebooks/YOURDRIVE/foo.txt', 'w') as f:
##   f.write('Hello Google Drive!')

# %% [markdown]
# ---

# %% [markdown]
# # #4. Practice

# %% [markdown]
# ## World happiness score and influenctial  factors
#
# Load the dataset (World_Happiness_2022.csv) into a data frame using Pandas and explore it.

# %%
# set up the notebook for plotting and import the packages 

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import seaborn as sns
import folium
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
happy_path = "https://raw.githubusercontent.com/ykjoy/data_visualization/main/World_Happiness_2022.csv"
happy_df = pd.read_csv(happy_path)
happy_df.head()
# Out:
#    RANK      Country          Region  Happiness score  GDP per capita  \
# 0     1      Finland  Western Europe            7.821           1.892
# 1     2      Denmark  Western Europe            7.636           1.953
# 2     3      Iceland  Western Europe            7.557           1.936
# 3     4  Switzerland  Western Europe            7.512           2.026
# 4     5  Netherlands  Western Europe            7.415           1.945
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.258                    0.775                         0.736
# 1           1.243                    0.777                         0.719
# 2           1.320                    0.803                         0.718
# 3           1.226                    0.822                         0.677
# 4           1.206                    0.787                         0.651
#
#    Generosity  Perceptions of corruption
# 0       0.109                      0.534
# ...

# %%
happy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   RANK                          146 non-null    int64
#  1   Country                       146 non-null    object
#  2   Region                        146 non-null    object
#  3   Happiness score               146 non-null    float64
#  4   GDP per capita                146 non-null    float64
#  5   Social support                146 non-null    float64
#  6   Healthy life expectancy       146 non-null    float64
#  7   Freedom to make life choices  146 non-null    float64
#  8   Generosity                    146 non-null    float64
#  9   Perceptions of corruption     146 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 11.5+ KB

# %%
happy_df.describe()
# Out:
#              RANK  Happiness score  GDP per capita  Social support  \
# count  146.000000       146.000000      146.000000      146.000000
# mean    73.500000         5.553575        1.410445        0.905863
# std     42.290661         1.086843        0.421663        0.280122
# min      1.000000         2.404000        0.000000        0.000000
# 25%     37.250000         4.888750        1.095500        0.732000
# 50%     73.500000         5.568500        1.445500        0.957500
# 75%    109.750000         6.305000        1.784750        1.114250
# max    146.000000         7.821000        2.209000        1.320000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               146.000000                    146.000000  146.000000
# mean                  0.586171                      0.517226    0.147377
# std                   0.176336                      0.145859    0.082799
# ...

# %% [markdown]
# ### Example. Which are the top 10 happiest countries?

# %%
happy_df.sort_values("Happiness score", ascending=False).head(10)
# Out:
#    RANK      Country                        Region  Happiness score  \
# 0     1      Finland                Western Europe            7.821
# 1     2      Denmark                Western Europe            7.636
# 2     3      Iceland                Western Europe            7.557
# 3     4  Switzerland                Western Europe            7.512
# 4     5  Netherlands                Western Europe            7.415
# 5     6   Luxembourg                Western Europe            7.404
# 6     7       Sweden                Western Europe            7.384
# 7     8       Norway                Western Europe            7.365
# 8     9       Israel  Middle East and North Africa            7.364
# 9    10  New Zealand         North America and ANZ            7.200
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.892           1.258                    0.775
# 1           1.953           1.243                    0.777
# ...

# %%
happy_df.head(10)  ## same results
# Out:
#    RANK      Country                        Region  Happiness score  \
# 0     1      Finland                Western Europe            7.821
# 1     2      Denmark                Western Europe            7.636
# 2     3      Iceland                Western Europe            7.557
# 3     4  Switzerland                Western Europe            7.512
# 4     5  Netherlands                Western Europe            7.415
# 5     6   Luxembourg                Western Europe            7.404
# 6     7       Sweden                Western Europe            7.384
# 7     8       Norway                Western Europe            7.365
# 8     9       Israel  Middle East and North Africa            7.364
# 9    10  New Zealand         North America and ANZ            7.200
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.892           1.258                    0.775
# 1           1.953           1.243                    0.777
# ...

# %%
happy_df.tail(3)
# Out:
#      RANK      Country                        Region  Happiness score  \
# 143   144     Zimbabwe            Sub-Saharan Africa            2.995
# 144   145      Lebanon  Middle East and North Africa            2.955
# 145   146  Afghanistan                    South Asia            2.404
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 143           0.947           0.690                    0.270
# 144           1.392           0.498                    0.631
# 145           0.758           0.000                    0.289
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 143                         0.329       0.106                      0.105
# 144                         0.103       0.082                      0.034
# 145                         0.000       0.089                      0.005

# %%
happy10= happy_df.head(10).copy()
x= happy10["Country"]
y= happy10["Happiness score"]

# Set the width and height of the figure
plt.figure(figsize=(15,4))
plt.plot(x, y, marker='s', color='blue')

plt.xlabel('Countries')
plt.ylabel('Happiness Score')

plt.title("Top 10 Happiest Countries")
plt.show()

# %% [markdown]
# ## Group Exercise
#
# With the following dataset,
#
# * <font color='red'>World Happiness Score</font>,  Gender Inequality Index, Gender Development Index
#
# <font color='red'> Take 3 quizzes </font> either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn/Folium.
#
# * Line, Scatter, Bar, Histogram, Joint, Pair, Heatmap, Pie, Stack, 3D Plots, Maps, etc.
#
# Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary.

# %% [markdown]
# ### Quiz 1. What are the happiness scores of Cambodia, Indonesia, Laos, South Korea, and Vietnam?

# %%
happy_unitwin= happy_df[happy_df['Country'].isin (['Cambodia','Indonesia','Laos','South Korea','Vietnam' ])]

x= happy_unitwin["Country"]
y= happy_unitwin["Happiness score"]

plt.__________(figsize=(10,4))
plt.__________(x, y)
plt.ylabel("Happiness score")
plt.show()

# %% [markdown]
# ### Quiz 2. Is there correlation between Happiness score and Economy of the countries (GDP per capita)?

# %% [markdown]
# **According to [Economist](https://www.economist.com/graphic-detail/2019/03/21/economic-growth-does-not-guarantee-rising-happiness), self-reported happiness tends to be higher in richer countries, but does not always rise when economies grow.

# %%
plt.__________(figsize=(10,4))
plt.__________(happy_df["Happiness score"], happy_df["GDP per capita"], marker ='o')
plt.title("Happiness score vs GDP per capita")
plt.________("Happiness score", size=14)
plt.ylabel("GDP per capia", size=14) 
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x ="Happiness score",  y = "GDP per capita", data=happy10, hue="Country")
plt.title("Happiness score vs GDP per capita")
plt.xlabel("Happiness score", size=14)
plt.ylabel("GDP per capia", size=14) 
plt.show()

# %%
sns.__________(x ="Happiness score",  y = "GDP per capita", data=happy_df, kind='reg')

# %% [markdown]
# ### Quiz 3. Show the relationship of happiness score to other factors.

# %%
sns._________(happy_df[['Happiness score', 'Social support', 'Healthy life expectancy',  'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']])

# %%
data_corr =happy_df[['Happiness score', 'GDP per capita', 'Social support', 'Healthy life expectancy',  'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']].corr()            
data_corr
# Out:
#                               Happiness score  GDP per capita  Social support  \
# Happiness score                      1.000000        0.763677        0.777889
# GDP per capita                       0.763677        1.000000        0.722421
# Social support                       0.777889        0.722421        1.000000
# Healthy life expectancy              0.740260        0.815386        0.666760
# Freedom to make life choices         0.624822        0.458591        0.480466
# Generosity                           0.063785       -0.164472       -0.002339
# Perceptions of corruption            0.416216        0.377589        0.223352
#
#                               Healthy life expectancy  \
# Happiness score                              0.740260
# GDP per capita                               0.815386
# Social support                               0.666760
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.433166
# ...

# %%
sns._________(_________, cmap='viridis', linewidths=2.0, linecolor='white', annot=True)

# %% [markdown]
# ### Quiz 4. Draw a choropleth map showing the geographical distribution of happiness score.

# %%
# !pip install folium
# !pip install country_converter

# %%
## add country code 
import country_converter as coco
happy_df['code']=coco.convert(names=list(happy_df['Country']), to='ISO3')
happy_df.head()
# Out:
#    RANK      Country          Region  Happiness score  GDP per capita  \
# 0     1      Finland  Western Europe            7.821           1.892
# 1     2      Denmark  Western Europe            7.636           1.953
# 2     3      Iceland  Western Europe            7.557           1.936
# 3     4  Switzerland  Western Europe            7.512           2.026
# 4     5  Netherlands  Western Europe            7.415           1.945
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.258                    0.775                         0.736
# 1           1.243                    0.777                         0.719
# 2           1.320                    0.803                         0.718
# 3           1.226                    0.822                         0.677
# 4           1.206                    0.787                         0.651
#
#    Generosity  Perceptions of corruption code
# 0       0.109                      0.534  FIN
# ...

# %%
happy_df[["code", "Happiness score"]]
# Out:
#     code  Happiness score
# 0    FIN            7.821
# 1    DNK            7.636
# 2    ISL            7.557
# 3    CHE            7.512
# 4    NLD            7.415
# ..   ...              ...
# 141  BWA            3.471
# 142  RWA            3.268
# 143  ZWE            2.995
# 144  LBN            2.955
# 145  AFG            2.404
#
# [146 rows x 2 columns]

# %%
happy_df[happy_df['Country'] =='Indonesia' ]
# Out:
#     RANK    Country          Region  Happiness score  GDP per capita  \
# 86    87  Indonesia  Southeast Asia             5.24           1.382
#
#     Social support  Healthy life expectancy  Freedom to make life choices  \
# 86           0.883                    0.539                          0.62
#
#     Generosity  Perceptions of corruption code
# 86       0.468                      0.047  IDN

# %%
# We need a GeoJSON file  that contains lists of world countries.
world_geo = "https://raw.githubusercontent.com/ykjoy/data_visualization/main/world_countries.json"

happy_map = folium.Map(location=[40, -4], zoom_start=2)  

folium.Choropleth(
    geo_data=world_geo,
    name="choropleth",
    data=happy_df,
    columns=["code", "Happiness score"],
    key_on="feature.id",   # id: AL, AK AZ
    fill_color="YlGn",
    fill_opacity=0.9,
    line_opacity=0.5,
    legend_name= "Happiness Score", 
    nan_fill_color="white"
).add_to(happy_map)

folium.LayerControl().add_to(happy_map)

# %%
happy_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# We need a GeoJSON file  that contains lists of world countries.
world_geo = "https://raw.githubusercontent.com/ykjoy/data_visualization/main/world_countries.json"

total_map = folium.Map(location=[48, -4], zoom_start=2)

list_of_index=['Happiness score', 'GDP per capita', 'Social support', 'Healthy life expectancy',  'Freedom to make life choices', 'Generosity', 'Perceptions of corruption' ]

for x in list_of_index:
  folium.Choropleth(
      geo_data=world_geo,
      name=x,
      data=happy_df,
      columns=['code', x],
      key_on='feature.id',
      fill_color='YlGn',
      fill_opacity=0.7,
      line_opacity=0.2,
      legend_name=x, 
      nan_fill_color='white'
   ).add_to(total_map)

folium.LayerControl(collapsed=False).add_to(total_map)

# %%
total_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### Takeaways
#
# What are the takeaways from your answers?
# *
# *
# *

# %% [markdown]
# ---
